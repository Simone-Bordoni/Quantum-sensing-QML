# %%
from qsopt import * 
import numpy as np
import matplotlib.pyplot as plt
import jax
import jax.numpy as jnp
import qutip

print(f"JAX version: {jax.__version__}")
print(f"QuTiP version: {qutip.__version__}")
print(f"JAX backend: {jax.default_backend()}")
devices = jax.devices()
print(f"JAX devices: {devices}")
print(f"JAX GPU available: {any(d.platform == 'gpu' for d in devices)}")
# Out:
# JAX version: 0.9.2
# QuTiP version: 5.2.2
# JAX backend: cpu
# JAX devices: [CpuDevice(id=0)]
# JAX GPU available: False

# %% [markdown]
# ## Define experimental parameters

# %%
chi = 7
eps = chi*2
kappa = 0.01


# Define interactions
interactions = [
    Interaction(interaction_type = InteractionType.DISPERSIVE,
                subsystem1 = ('cavity',0),
                subsystem2 = ('qubit',0),
                parameters = {'chi': chi}
                ),
    Interaction(interaction_type = InteractionType.DISSIPATION,
                subsystem1 = ('cavity', 0),
                parameters = {'kappa': kappa})
]

# Define custom physical model
physical_model = PhysicalModel(
    perturbation_type = 'persistent',
    n_cavities = 1,
    n_fields = 1,
    n_qubits = 2,
    cavity_levels = 4,
    field_levels = 1,
    qubit_levels = 2,
    interactions = interactions
)


# Define noise model
noise = NoiseModel(
    depolarizing=0.01,
    dephasing=0.01,
    relaxation=0.01
)

# Define measurement protocol
custom_times = TimeProtocol( #-6;-2;+2;+6;+10   +[-4;0] ->-10; ... ;+6
    t_simulation_start=-6,
    n_measurements=4,
    time_interval=4,
    random_measurements_offset=True,
    noisy_simulation_start=True
)

config_set = [
    SystemConfiguration(
        name = 'no drive',
        is_ground = True),
    SystemConfiguration(
        name = 'driven',
        interactions = [            
    Interaction(interaction_type = InteractionType.DRIVE,
            subsystem1 = ('cavity',0),
            parameters = {'amplitude': eps}
            ),
        ]),
]

# Create parameters with custom configuration
exp_parameters = ExperimentalParameters(
    physical_model=physical_model,
    noise_model=noise,
    time_protocol=custom_times,
    configuration_set=config_set
)

print(exp_parameters)
# Out:
# SYSTEM DIMENSIONS
#   Cavities: 1   levels [2]
#   Fields:   1   levels [2]
#   Qubits:   1   levels [2]
#   Total dimension: 8
#
# PHYSICAL MODEL
#   Perturbation type:    transient
#   Interactions:         4 interaction(s)
#   Static interactions:
#     dispersive(cavity0-qubit0): chi=7.5
#     depolarizing(qubit0): depolarizing=0.01
#     dephasing(qubit0): dephasing=0.01
#     relaxation(qubit0): relaxation=0.01
#
# TIME PROTOCOL
#   Start time:            -6.0000
#   Mode:                 Interval-based
#   Time interval:          4.0000
#   Number of measurements:      4
#   Computed times:       [-2.0, 2.0, 6.0, 10.0]
#   Collective offset:    uniform(-4, 0)
#   Per-measurement jitter: none
#   Noisy simulation start: on
#   Measurement window:   None (uniform weights)
#
# NOISE MODEL
#   Depolarizing rate:    [0.01]
#   Dephasing rate:       [0.01]
#   Relaxation rate:      [0.01]
#   Custom operators:     None
#
# CONFIGURATIONS
#   Count:                2
#   Ground configuration: no interaction
#     [0] no interaction (ground): noise_override=no, interactions=0
#       Cavity 0: vacuum
#       Field 0: fock(n=0)
#     [1] with interaction: noise_override=no, interactions=1
#       Cavity 0: vacuum
#       Field 0: fock(n=1)
#       Interactions:
#         input_output(cavity0-field0)
#
# SYSTEM STATUS
#   Configuration:        VALID
#
# RANDOM SEED
#   Seed:                 None

# %% [markdown]
# ## Optional, plot pulse shape

# %%
# from qsopt.utils.visualization import plot_pulse_shape_with_measurements

# fig = plot_pulse_shape_with_measurements(
#     exp_params=exp_parameters,
#     save_path='results/pulse_shape.png',
#     batch_size=1
# )
# fig.show()

# %% [markdown]
# ## Define quantum circuits
#
# The interface uses `QuantumCircuit` objects to define the gates applied before and after evolution.

# %%
import copy
from qsopt.core.circuit import QuantumCircuit, create_ry_circuit
from qsopt.core.gates import CNOTGate

initial_circuit = create_ry_circuit(n_qubits=2, theta_values=[np.pi/2])
initial_circuit.add_entangling_layer(CNOTGate, pattern='circular')
final_circuit = create_ry_circuit(n_qubits=2, theta_values=[-np.pi/2])
final_circuit.add_entangling_layer(CNOTGate, pattern='circular')

# The circuits contain trainable parameters that will be optimized
print(f"Initial circuit parameters: {initial_circuit.get_trainable_parameters()}")
print(initial_circuit)
print(f"Final circuit parameters: {final_circuit.get_trainable_parameters()}")
print(final_circuit)
# Out:
# Initial circuit parameters: [Array(1.57079633, dtype=float64)]
# QuantumCircuit(1 qubits, 1 gates)
#   0: RY[0](param=1.571)
# Final circuit parameters: [Array(-1.57079633, dtype=float64)]
# QuantumCircuit(1 qubits, 1 gates)
#   0: RY[0](param=-1.571)

# %% [markdown]
# ## Define experiment

# %%
detection_metric = DetectionMetric(n_cavities=1,
                                   n_fields=1,
                                   n_qubits=1,
                                   config_names=['with interaction','no interaction'],
                                   detection_criterion = 'trace distance',
                                   perturbation_type=physical_model.perturbation_type
                                   )

print(detection_metric)

experiment = Experiment(
    experimental_params=exp_parameters,
    initial_circuit=initial_circuit,
    final_circuit=final_circuit,
    detection_metric=detection_metric
)
# Out:
# DetectionMetric:
# maximize computational distance
# softmax aggregation, transient

# %%
# The generic N-D sweep takes a {parameter_name: values} grid. 'chi' is the dispersive coupling, 'gamma'
# the input-output coupling of the 'with interaction' config. Each grid point returns the metric,
# validation and per-configuration detection.
results_sweep = experiment.sweep(
    {'kappa': np.logspace(kappa*0.1, 100*kappa, 10), 
     'amplitude': np.logspace(eps*0.01, 10*eps, 10),
     'time_interval': np.linspace(1,6,5)},
    batch_size=8,
    verbose=True
)
print(results_sweep)
# Out:
# /home/nathan/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/src/qsopt/core/experiment/experiment.py:1582: UserWarning: batch_size=1 is too small to average measurement uncertainty consistently; using 16 instead.
#   warnings.warn(f"batch_size={batch_size} is too small to average measurement uncertainty "
# Sweeping 2 axes over 25 grid points (uncertainty on, 16 realizations/point):
#   - chi: 5 pts in [1, 20]  lane=promote  (BaseModel_dispersive(cavity0,qubit0)__chi)
#   - kappa: 5 pts in [1, 40]  lane=rebuild  (Conf:with interaction_input_output(cavity0,field0)__kappa)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 # The generic N-D sweep takes a {parameter_name: values} grid. 'chi' is the dispersive coupling, 'gamma'
#       2 # the input-output coupling of the 'with interaction' config. Each grid point returns the metric,
#       3 # validation and per-configuration detection.
# ----> 4 results_sweep = experiment.sweep(
#       5     {'chi': np.linspace(1.0, 20.0, 5), 'kappa': np.linspace(1.0, 40.0, 5)},
#       6     batch_size=1,
#       7     verbose=True
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/src/qsopt/core/experiment/experiment.py:1694, in Experiment.sweep(self, param_grid, time_protocol, batch_size, verbose)
#    1690 H, L, ga = build_hamiltonians(
#    1691     self.operators, self.experimental_params, self.n_cavities, self.n_fields, self.n_qubits,
#    1692     overrides=overrides, dynamic_keys=set(promote_keys) if promote_keys else None)
#    1693 solvers = {c: qt.MESolver(H[c], L[c], options=opts) for c in self.config_names}
# -> 1694 out_m, out_det, out_val = adaptive_map(make_eval(solvers, ga), fast_grid, verbose)
#    1696 slc = [slice(None)] * len(names)
#    1697 for i, ix in zip(loop_idx, loop_combo):
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/src/qsopt/core/core_utils.py:671, in adaptive_map(fn, grid, verbose)
#     668     backend = "gpu" if any(d.platform == "gpu" for d in jax.devices()) else "cpu"
#     670 if backend == "cpu":
# --> 671     outs = [fn(row) for row in grid]
#     672     return jax.tree_util.tree_map(lambda *leaves: jnp.stack(leaves), *outs)
#     674 bs = int(grid.shape[0])
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/src/qsopt/core/experiment/experiment.py:1683, in Experiment.sweep.<locals>.make_eval.<locals>.evaluate(point)
#    1681 noise = protocol.combine_noise(shift, corr, capped_jitter, xp=jnp)
#    1682 # average over the pre-drawn realizations
# -> 1683 m, det, val = jax.vmap(lambda nz: evaluate_at(meas_t + nz, args))(noise)
#    1684 return jnp.mean(m), jnp.mean(det, axis=0), jnp.mean(val)
#
#     [... skipping hidden 1 frame]
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/api.py:1217, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1214 try:
#    1215   axis_data = batching.AxisData(axis_name, axis_size_, spmd_axis_name,
#    1216                                 explicit_mesh_axis)
# -> 1217   out_flat, inferred_out_axes = batching.batch(
#    1218       flat_fun, axis_data, in_axes_flat,
#    1219       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes),
#    1220       sum_match=sum_match
#    1221   ).call_wrapped(*args_flat)
#    1222 except batching.SpecMatchError as e:
#    1223   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:375, in _batch_outer(f, axis_data, in_dims, *in_vals)
#     373 tag = TraceTag()
#     374 with source_info_util.transform_name_stack('vmap'):
# --> 375   outs, out_dim_srcs, trace = f(tag, in_dims, *in_vals)
#     376 with core.ensure_no_leaks(trace): del trace
#     377 return outs, out_dim_srcs
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:394, in _batch_inner(f, axis_data, out_dim_dests, sum_match, tag, in_dims, *in_vals)
#     388 # TODO(yashkatariya): Instead of `add_explicit_mesh_axis_names`, we should
#     389 # create a new mesh by removing the axis_data.explicit_mesh_axis from it.
#     390 with (core.set_current_trace(trace),
#     391       core.extend_axis_env_nd([(axis_data.name, axis_data.size)]),
#     392       core.add_spmd_axis_names(axis_data.spmd_name),
#     393       core.add_explicit_mesh_axis_names(axis_data.explicit_mesh_axis)):
# --> 394   outs = f(*in_tracers)
#     395   out_dim_dests = out_dim_dests() if callable(out_dim_dests) else out_dim_dests
#     396   out_vals, out_dim_srcs = unzip2(
#     397       map(partial(from_elt, trace, axis_data.size, axis_data.explicit_mesh_axis, sum_match),  # pyrefly: ignore[no-matching-overload]  # pyrefly#2385
#     398           range(len(outs)), outs, out_dim_dests))
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:120, in flatten_fun_for_vmap(f, store, in_tree, *args_flat)
#     116 @lu.transformation_with_aux2
#     117 def flatten_fun_for_vmap(f: Callable,
#     118                          store: lu.Store, in_tree: PyTreeDef, *args_flat):
#     119   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# --> 120   ans = f(*py_args, **py_kwargs)
#     121   ans, out_tree = tree_flatten(ans, is_leaf=is_vmappable)
#     122   store.store(out_tree)
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/src/qsopt/core/experiment/experiment.py:1683, in Experiment.sweep.<locals>.make_eval.<locals>.evaluate.<locals>.<lambda>(nz)
#    1681 noise = protocol.combine_noise(shift, corr, capped_jitter, xp=jnp)
#    1682 # average over the pre-drawn realizations
# -> 1683 m, det, val = jax.vmap(lambda nz: evaluate_at(meas_t + nz, args))(noise)
#    1684 return jnp.mean(m), jnp.mean(det, axis=0), jnp.mean(val)
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/src/qsopt/core/experiment/experiment.py:1656, in Experiment.sweep.<locals>.make_eval.<locals>.evaluate_at(meas_t, args)
#    1654 def evaluate_at(meas_t, args):
#    1655     """Metric/detections/validation for one timestamp realization."""
# -> 1656     rho = {c: self.simulation(solvers[c], rho0[c], meas_t, args=args, precomputed_unitaries=unis)
#    1657            for c in self.config_names}
#    1658     weights = protocol.measurement_weights(meas_t[1:])
#    1659     m, (det, val) = self.detection_metric(rho, weights=weights)
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/src/qsopt/core/experiment/experiment.py:426, in Experiment.simulation(self, solver, rho, measurements, args, precomputed_unitaries)
#     422 for t0, t1 in zip(measurements[:-1], measurements[1:]):
#     424     rho_after_circuit = initial_unitary * rho_current * initial_unitary_dag  # type: ignore
# --> 426     evolution_result = solver.run(rho_after_circuit, [t0, t1], args=args)
#     428     rho_evolved = evolution_result.states[-1]
#     429     rho_final = final_unitary * rho_evolved * final_unitary_dag  # type: ignore
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/qutip/solver/solver_base.py:207, in Solver.run(self, state0, tlist, e_ops, args)
#     202 stats['preparation time'] += time() - _time_start
#     204 progress_bar = progress_bars[self.options['progress_bar']](
#     205     len(tlist)-1, **self.options['progress_kwargs']
#     206 )
# --> 207 for t, state in self._integrator.run(tlist):
#     208     progress_bar.update()
#     209     results.add(t, self._restore_state(state, copy=False))
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/qutip/solver/integrator/integrator.py:201, in Integrator.run(self, tlist)
#     187 """
#     188 Integrate the system yielding the state for each times in tlist.
#     189
#    (...)    198     The state of the solver at each ``t`` of tlist.
#     199 """
#     200 for t in tlist[1:]:
# --> 201     yield self.integrate(t, False)
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/qutip_jax/ode.py:70, in DiffraxIntegrator.integrate(self, t, copy, **kwargs)
#      68 if kwargs:
#      69     self.arguments(kwargs)
# ---> 70 sol = diffrax.diffeqsolve(
#      71     self.ODEsystem,
#      72     t0=self.t,
#      73     t1=t,
#      74     y0=self.state,
#      75     saveat=diffrax.SaveAt(t1=True, solver_state=True),
#      76     solver_state=self.solver_state,
#      77     args=(self.system,),
#      78     **self._options,
#      79 )
#      80 self.t = t
#      81 self.state = sol.ys[0, :]
#
#     [... skipping hidden 3 frame]
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:256, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     252   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     253                      "`jit`, but 'no_tracing' is set")
#     254 p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     255 (outs, out_flat, out_tree, args_flat, jaxpr,
# --> 256  executable, pgle_profiler, const_args) = _run_python_pjit(
#     257      p, args_flat, fun, args, kwargs)
#     259 maybe_fastpath_data = _get_fastpath_data(
#     260     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     261     pgle_profiler, const_args)
#     263 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:144, in _run_python_pjit(p, args_flat, fun, args, kwargs)
#     141   out_flat, compiled, profiler, const_args = _pjit_call_impl_python(
#     142       *args_flat, **p.params)
#     143 else:
# --> 144   out_flat = jit_p.bind(*args_flat, **p.params)
#     145   compiled = None
#     146   profiler = None
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/core.py:648, in Primitive.bind(self, *args, **params)
#     646 trace_ctx.set_trace(eval_trace)
#     647 try:
# --> 648   return self.bind_with_trace(prev_trace, args, avals, params)
#     649 finally:
#     650   trace_ctx.set_trace(prev_trace)
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/core.py:656, in Primitive.bind_with_trace(self, trace, args, avals, params)
#     654   with set_current_trace(trace):
#     655     return self.to_lojax(*args, **params)  # type: ignore
# --> 656 return trace.process_primitive(self, args, params)
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/interpreters/batching.py:260, in BatchTrace.process_primitive(self, p, tracers, params)
#     255 if p in fancy_primitive_batchers:
#     256   # TODO(yashkatariya): Remove remove_explicit_mesh_axis_names when vmap
#     257   # mesh ctx is correctly set.
#     258   with (core.set_current_trace(self.parent_trace),
#     259         core.remove_explicit_mesh_axis_names(self.axis_data.explicit_mesh_axis)):
# --> 260     val_out, dim_out = fancy_primitive_batchers[p](
#     261         self.axis_data, vals_in, dims_in, **params)
#     262     src = source_info_util.current()
#     263     if p.multiple_results:
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:1444, in _pjit_batcher(axis_data, vals_in, dims_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs)
#    1439 if not (all(l is None for l in in_layouts) and
#    1440         all(l is None for l in out_layouts)):
#    1441   raise NotImplementedError(
#    1442       'Concrete layouts are not supported for vmap(jit).')
# -> 1444 vals_out = jit_p.bind(
#    1445   *vals_in,
#    1446   jaxpr=new_jaxpr,
#    1447   in_shardings=in_shardings,
#    1448   out_shardings=out_shardings,
#    1449   in_layouts=in_layouts,
#    1450   out_layouts=out_layouts,
#    1451   donated_invars=donated_invars,
#    1452   ctx_mesh=ctx_mesh,
#    1453   name=name,
#    1454   keep_unused=keep_unused,
#    1455   inline=inline,
#    1456   compiler_options_kvs=compiler_options_kvs)
#    1458 return vals_out, axes_out
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/core.py:648, in Primitive.bind(self, *args, **params)
#     646 trace_ctx.set_trace(eval_trace)
#     647 try:
# --> 648   return self.bind_with_trace(prev_trace, args, avals, params)
#     649 finally:
#     650   trace_ctx.set_trace(prev_trace)
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/core.py:656, in Primitive.bind_with_trace(self, trace, args, avals, params)
#     654   with set_current_trace(trace):
#     655     return self.to_lojax(*args, **params)  # type: ignore
# --> 656 return trace.process_primitive(self, args, params)
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/core.py:1217, in EvalTrace.process_primitive(self, primitive, args, params)
#    1215 args = map(full_lower, args)
#    1216 check_eval_args(args)
# -> 1217 return primitive.impl(*args, **params)
#
# File ~/Documenti/Università/Magistrale/Tesi Magistrale/Quantum-sensing-QML/.venv/lib/python3.13/site-packages/jax/_src/pjit.py:1231, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1223 donated_argnums = tuple(i for i, d in enumerate(donated_invars) if d)
#    1224 cache_key = pxla.JitGlobalCppCacheKeys(
#    1225     donate_argnums=donated_argnums, donate_argnames=None,
#    1226     device=None, backend=None,
#    (...)   1229     in_layouts_treedef=None, in_layouts_leaves=in_layouts,
#    1230     out_layouts_treedef=None, out_layouts_leaves=out_layouts)
# -> 1231 return xc._xla.pjit(
#    1232     name, f, call_impl_cache_miss, [], [], cache_key,
#    1233     tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1234     _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#
# KeyboardInterrupt:

# %%
from qsopt.utils.visualization import plot_sweep_results

# A 2D sweep draws one contour panel per selected quantity (metric, validation and each detection
# config). 'display_axes' chooses which axes go on x/y (defaults to the first two); toggle the
# quantities with show_metric / show_validation / show_detection.
plot_sweep_results(results_sweep, show_detection=False, show_metric=False)
plt.show()

# %% [markdown]
# ## Test Single Simulation

# %%
# run_simulation returns the metrics (metric, validation, per-configuration detection). The deployable
# detection protocol (states map, joint confusion matrix, false signal and full probability tree) is
# built by make_protocol from the branching simulation.
results = experiment.run_simulation(batch_size=16)
print(results)

protocol = experiment.make_protocol(batch_size=16)
print(protocol)
# Out:
# MODE: Single Simulation
#   Experiment metadata:  absent
#   Current Parameters:
#      Initial circuit:
#         param_0: 1.570796 rad (90.00°)
#      Final circuit:
#         param_0: -1.570796 rad (-90.00°)
#   Detection Measures:
#      no interaction   : 0.000000
#      with interaction : 0.000000
#   Objective:
#      Metric:     0.601102
#      Validation: 0.601102
# MODE: Single Simulation
#   Experiment metadata:  absent
#   Detection Protocol (states classified per configuration):
#      no interaction: ['0']
#      with interaction: ['1']
#   False signal (joint, per configuration):
#      no interaction: 0.2554
#      with interaction: 0.0000
#   Confusion Matrix (rows: true, cols: predicted):
#                            no interaction  with interaction             mixed
#          no interaction            0.7446            0.2554            0.0000
#        with interaction            0.0596            0.9404            0.0000

# %% [markdown]
# ## Time Evolution

# %%
# result = experiment.time_evolution(n_points=300, with_interaction=True)
# print(result)

# from qsopt.utils.visualization import plot_time_evolution
# plot_time_evolution(
#     evolution_data=result,
#     show_pulse=True,
#     show_measurements=True,
#     show_cavity_population=True,  # Cavity population (purple)
#     show_field_population=True,   # External field population (brown)
#     title='Single Qubit Evolution',
#     figsize=(10, 6),
#     normalize_detection = True
# )
# plt.show()

# %% [markdown]
# ## Run Optimization

# %%
import optax

# Use an explicit callback so this history is not overwritten by later optimizations
history_callback = OptimizationCallback(save_every=1, save_best=True)

history = experiment.optimize_rotations(
    initial_values=[ 0.4, -1.1], 
    num_steps=150,
    verbose=True,
    verbose_step=25,
    batch_size=16,
    tolerance=1e-7,
    callback=history_callback,
    optimizer=optax.sgd(learning_rate=0.1),
    anneal_tolerances=1000
)
# Out:
# Configuration:
#     Max iterations: 150
#     Batch size: 16
#     Convergence tolerance: 1.00e-07
#     Detection metric:
# maximize computational distance
# softmax aggregation, transient
#     Trainable parameters: 2 (1 initial circuit + 1 final circuit)
#     Initial parameter values:
#         param0.  setup_RY[0]  = 0.400  rad (22.9°)
#         param1.  reset_RY[0]  = -1.100 rad (-63.0°)
#     Measurement uncertainty: collective offset uniform(-4, 0), per-measurement jitter off
# =================================================================================
# Step  setup0_RY[0]   reset0_RY[0]   Metric      Validation  Grad Norm   Time
# ---------------------------------------------------------------------------------
# 0     0.400000       -1.100000      0.075027    0.145816    1.83e-01    00h00m33s
# 1     0.417891       -1.103850      0.078466    0.150326    1.83e-01    00h00m34s
# 2     0.435736       -1.107845      0.081951    0.164276    1.83e-01    00h00m35s
# 25    0.825491       -1.229084      0.159514    0.377718    1.69e-01    00h00m53s
# 50    1.176982       -1.379645      0.241803    0.542944    1.34e-01    00h01m12s
# 75    1.417158       -1.494877      0.326761    0.604162    7.77e-02    00h01m31s
# 100   1.530308       -1.550726      0.421312    0.598032    2.73e-02    00h01m50s
# 125   1.563401       -1.567126      0.543346    0.622122    6.01e-03    00h02m09s
# =================================================================================
# Total optimization time: 00h02m46s
# Final gradient norm: 9.82e-04
# Best validation: 0.628746
# Best metric (at best validation): 0.628746
# Best parameters:
#     param0. setup_RY[0](param=1.569)=1.569 rad (89.9°)
#     param1. reset_RY[0](param=-1.570)=-1.570 rad (-90.0°)

# %%
# Free GPU/JAX memory after optimization
jax.clear_caches()
import gc; gc.collect()
# Out:
# 1380

# %%
# make_protocol on a callback loads its best parameters onto the circuits and stores the detection
# protocol (states map, joint confusion matrix, false signal and probability tree) onto it.
history = experiment.make_protocol(callback=history, batch_size=16)
print(history)
# Out:
# MODE: Optimization
#      Total iterations: 150
#      Best epoch:        147
#      Converged: False
#      Final gradient norm: 9.817404e-04
#   Experiment metadata:  present (use print_metadata())
#   Best Parameters:
#      Initial circuit:
#         param_0: 1.569381 rad (89.92°)
#      Final circuit:
#         param_0: -1.570091 rad (-89.96°)
#   Detection Measures:
#      no interaction   : 0.000000
#      with interaction : 0.000000
#   Objective:
#      Metric:     0.628746
#      Validation: 0.628746
#   Detection Protocol (states classified per configuration):
#      no interaction: ['0']
#      with interaction: ['1']
#   False signal (joint, per configuration):
#      no interaction: 0.2554
#      with interaction: 0.0000
#   Confusion Matrix (rows: true, cols: predicted):
#                            no interaction  with interaction             mixed
#          no interaction            0.7446            0.2554            0.0000
#        with interaction            0.0604            0.9396            0.0000

# %%
from qsopt.utils.visualization import plot_optimization_dashboard

# Create comprehensive dashboard with all plots enabled
fig = plot_optimization_dashboard(
    optimization_callback=history,
    reference_callback=results,
    show_metric=True,
    show_gradients=True,
    show_parameters=True,
    show_detection_measures=False,
    show_trajectory=True,
    show_confusion_matrix=True,
    show_mixed_column=False,
    figsize=(16,24),
    save_path='results/rotations_opt_dashboard.pdf'  # Save to file
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 from qsopt.utils.visualization import plot_optimization_dashboard
#       2
#       3 # Create comprehensive dashboard with all plots enabled
#       4 fig = plot_optimization_dashboard(
# ----> 5     optimization_callback=history,
#       6     reference_callback=results,
#       7     show_metric=True,
#       8     show_gradients=True,
#
# NameError: name 'history' is not defined

# %% [markdown]
# ## Sweep Measurement Times

# %%
# Sweep over 'time_interval': it re-spaces the M measurements as t0 + [0, v, ..., M*v] for each interval
# v. A measurement-times sweep needs a fixed measurement WINDOW so the metric is scored over the same
# region of interest as the spacing changes; the sweep also requires the measurements to span the window
# (M*min(v) >= window_end - t0). Here t0 = t_simulation_start = -10 and the input pulse diverges for large
# positive t, so the interval is bounded below (span check) and above (measurements stay <~ 10): v in [3.2, 4.0].
windowed_protocol  = TimeProtocol(
    t_simulation_start=-4,
    n_measurements=20,
    time_interval=4,
    random_measurements_offset=True,
    per_measurement_jitter=0.01,
    noisy_simulation_start=True,
    window_start= -2,
    window_end=8
)
results_time_sweep = experiment.sweep(
    {'time_interval': np.linspace(0.75, 12.0, 20)},
    time_protocol=windowed_protocol,
    batch_size=64,
    verbose=True
)
print(results_time_sweep)
# Out:
# Sweeping 1 axes over 20 grid points (uncertainty on, 64 realizations/point):
#   - time_interval: 20 pts in [0.75, 12]  lane=measurement  (measurement times)
# Best metric 0.674068 at {'time_interval': 4.894736842105263}
# SweepResults:
#   Axis 0 (time_interval): [0.75, 12], linear, 20 points
#   Available results: detection_no interaction, detection_with interaction, metric, validation

# %%
from qsopt.utils.visualization import plot_sweep_results

# A 1D sweep draws one line per selected quantity. metric / validation / detection are each
# togglable (all True by default); here we hide the per-configuration detection lines.
plot_sweep_results(results_time_sweep, show_detection=False, show_metric=False, figsize=(7, 4))
plt.show()

# %% [markdown]
# ## Sweep chi-kappa

# %%
# The generic N-D sweep takes a {parameter_name: values} grid. 'chi' is the dispersive coupling, 'gamma'
# the input-output coupling of the 'with interaction' config. Each grid point returns the metric,
# validation and per-configuration detection.
results_sweep = experiment.sweep(
    {'chi': np.linspace(1.0, 20.0, 10), 'kappa': np.linspace(1.0, 40.0, 10)},
    batch_size=32,
    verbose=True
)
print(results_sweep)
# Out:
# Sweeping 2 axes over 100 grid points (uncertainty on, 32 realizations/point):
#   - chi: 10 pts in [1, 20]  lane=promote  (BaseModel_dispersive(cavity0,qubit0)__chi)
#   - kappa: 10 pts in [1, 40]  lane=rebuild  (Conf:with interaction_input_output(cavity0,field0)__kappa)
# Best metric 0.590839 at {'chi': 20.0, 'kappa': 40.0}
# SweepResults:
#   Axis 0 (chi): [1, 20], linear, 10 points
#   Axis 1 (kappa): [1, 40], linear, 10 points
#   Available results: detection_no interaction, detection_with interaction, metric, validation

# %%
from qsopt.utils.visualization import plot_sweep_results

# A 2D sweep draws one contour panel per selected quantity (metric, validation and each detection
# config). 'display_axes' chooses which axes go on x/y (defaults to the first two); toggle the
# quantities with show_metric / show_validation / show_detection.
plot_sweep_results(results_sweep, show_detection=False, show_metric=False)
plt.show()

# %% [markdown]
# ## Sweep in more than two dimensions
#
# `experiment.sweep` takes any number of axes. Below we sweep four at once: the pulse bandwidth `sigma`, the input–output rate `kappa` (the `k` of the INPUT_OUTPUT interaction), the dispersive coupling `chi`, and the measurement `time_interval`.
#
# A scalar map over 4 axes can't be drawn directly, so there are three views:
#
# - **`plot_sweep_results`** shows a *slice*: it plots one or two axes and fixes the rest at the optimum (or at values you pass via `fixed={'axis': value}`).
# - **`plot_sweep_corner`** shows *every axis pair at once* — upper triangle slices through the optimum, lower triangle max-projects over the hidden axes, diagonal is the 1D max-projection per axis.
# - **`interactive_sweep`** is a live explorer (`ipywidgets`) with a slider per hidden axis.

# %%
# 4D sweep: sigma (pulse bandwidth), kappa (the 'k' of the INPUT_OUTPUT interaction), chi (dispersive
# coupling) and the measurement time_interval. Kept small (4 points/axis) so it runs quickly — raise
# the resolutions for smoother maps. Reuses windowed_protocol from the measurement-times sweep above,
# since a time_interval axis needs a fixed measurement window.
results_hd = experiment.sweep(
    {
        'sigma': np.linspace(0.6, 1.4, 4),
        'kappa': np.linspace(8.0, 20.0, 4),
        'chi': np.linspace(1.0, 20.0, 4),
        'time_interval': np.linspace(3.2, 4.0, 4),
    },
    time_protocol=windowed_protocol,
    batch_size=32,
    verbose=True,
)
print(results_hd)
# Out:
# Sweeping 4 axes over 256 grid points (uncertainty on, 32 realizations/point):
#   - sigma: 4 pts in [0.6, 1.4]  lane=promote  (Conf:with interaction_input_output(cavity0,field0)__sigma)
#   - kappa: 4 pts in [8, 20]  lane=rebuild  (Conf:with interaction_input_output(cavity0,field0)__kappa)
#   - chi: 4 pts in [1, 20]  lane=promote  (BaseModel_dispersive(cavity0,qubit0)__chi)
#   - time_interval: 4 pts in [3.2, 4]  lane=measurement  (measurement times)
# Best metric 0.691541 at {'sigma': 1.4, 'kappa': 16.0, 'chi': 7.333333333333333, 'time_interval': 4.0}
# SweepResults:
#   Axis 0 (sigma): [0.6, 1.4], linear, 4 points
#   Axis 1 (kappa): [8, 20], linear, 4 points
#   Axis 2 (chi): [1, 20], linear, 4 points
#   Axis 3 (time_interval): [3.2, 4], linear, 4 points
#   Available results: detection_no interaction, detection_with interaction, metric, validation

# %% [markdown]
# ### Corner view — every axis pair at once

# %%
from qsopt.utils.visualization import plot_sweep_corner

# One quantity across every axis pair. Upper triangle: 2D slice through the optimum. Lower triangle:
# max-projection over the hidden axes. Diagonal: 1D max-projection. Choose the map with
# quantity='metric' | 'validation' | 'detection' (and config=<name> for detection).
plot_sweep_corner(results_hd, quantity='validation')
plt.show()

# %% [markdown]
# ### Interactive explorer

# %%
from qsopt.utils.visualization import interactive_sweep

# Live explorer (needs ipywidgets, installed with the package). Dropdowns pick the quantity and the
# two shown axes; a slider per remaining axis moves the slice. Set 'hidden' to max/mean to project
# over the hidden axes instead of slicing.
interactive_sweep(results_hd)
# Out:
# VBox(children=(HBox(children=(Dropdown(description='quantity', options=('metric', 'validation', 'detection:no …
