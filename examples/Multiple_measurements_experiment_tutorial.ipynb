# %% [markdown]
# ## Experiment Tutorial: Multiple Measurements

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
from qsopt.core.experimental_parameters import (
    ExperimentalParameters,
    PhysicalConstants,
    SystemDimensions,
    MeasurementProtocol,
    InteractionType,
    QubitInteraction,
    InitialStateConfig,
    InitialStateType,
    NoiseConfiguration
)
from qsopt.core.circuit import QuantumCircuit, create_ry_circuit_layer
from qsopt.core.experiment.experiment import Experiment

# Suppress warnings for cleaner output
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Setup Experimental Parameters

# %%
# Define experimental parameters using nested configuration objects
interaction = QubitInteraction(
    qubit_indices=(0, 1),
    interaction_type=InteractionType.XX,
    chi=0.1
)

physical_constants = PhysicalConstants(
    n_qubits=2,
    chi=[30.0, 30.0],
    photon_cavity_coupling=15.0,
    inverse_pulse_width=1.0,
    qubit_interactions=[interaction]
)

system_dims = SystemDimensions(
    field_levels=2,
    cavity_levels=2,
    qubit_levels=[2, 2]
)

measurement = MeasurementProtocol(
    measurement_times=[-8.0, -4.0, 0, 4.0, 8.0] 
)

initial_state = InitialStateConfig(state_type=InitialStateType.SINGLE_PHOTON)

noise_config = NoiseConfiguration(
    depolarizing=[0.0, 0.0],
    dephasing=[0.0, 0.0],
    relaxation=[0.0, 0.0]
)

exp_params = ExperimentalParameters(
    physical_constants=physical_constants,
    system_dims=system_dims,
    measurement=measurement,
    initial_state=initial_state,
    noise_config=noise_config
)

print(exp_params)
# Out:
# SYSTEM DIMENSIONS
#   Number of qubits:          2
#   Cavity levels:             2
#   Qubit levels:         [2, 2]
#   Field levels:              2
#   Total dimension:          16
# PHYSICAL CONSTANTS
#   Chi:                  [30.0, 30.0]
#   Photon cavity coupling: 15.0000
#   Inverse pulse width:    1.0000
#   Qubit interactions:   1 interaction(s)
#     [0] Qubits (0, 1): sx-sx, χ=0.1000
# MEASUREMENT PROTOCOL
#   Mode:                 Explicit list
#   Number of measurements:      5
#   Measurement times:    [-8.0, -4.0, 0.0, 4.0, 8.0]
# INITIAL STATE
#   Type:                 single_photon
# NOISE MODEL
#   Depolarizing rate:    [0.0, 0.0]
#   Dephasing rate:       [0.0, 0.0]
#   Relaxation rate:      [0.0, 0.0]
#   Custom operators:     None
# SYSTEM STATUS
#   Configuration:        VALID

# %% [markdown]
# ## 2. Setup Trainable Parameters
#
# For two-qubit experiments, we need 4 rotation angles:
# - θ1_q1, θ2_q1: Rotation angles for qubit 1
# - θ1_q2, θ2_q2: Rotation angles for qubit 2

# %%
# Create Circuit with 4 rotation angles

initial_circuit = create_ry_circuit_layer(n_qubits=2, theta_values=np.pi/2)
final_circuit = create_ry_circuit_layer(n_qubits=2, theta_values=-np.pi/2)

print(initial_circuit)
print(final_circuit)
# Out:
# QuantumCircuit(2 qubits, 2 gates)
#   0: RY(1.5708)[0][0]
#   1: RY(1.5708)[1][1]
# QuantumCircuit(2 qubits, 2 gates)
#   0: RY(-1.5708)[0][0]
#   1: RY(-1.5708)[1][1]

# %% [markdown]
# ## 3. Create Two-Qubit Experiment
#
# Initialize the experiment with our parameters. This will:
# - Generate operators for the 4-subsystem composite space
# - Build the time-dependent Hamiltonian
# - Cache initial state and projectors

# %%
experiment = Experiment(exp_params, initial_circuit, final_circuit)

# %% [markdown]
# ## 4. Run Basic Simulation

# %%
# Run simulation with zero rotations
callback = experiment.run_simulation(batch_size=1)

print(callback)
# Out:
# MODE: Single Simulation
#   Current Parameters:
#      Initial circuit:
#         param_0: 1.570796 rad (90.00°)
#         param_1: 1.570796 rad (90.00°)
#      Final circuit:
#         param_0: -1.570796 rad (-90.00°)
#         param_1: -1.570796 rad (-90.00°)
#   Detection Probabilities:
#      P(with photon):    0.999467
#      P(without photon): 0.000000
#      Contrast:          0.999467

# %% [markdown]
# ## 5. Optimize Rotation Angles
#
# Now let's optimize the four rotation angles to maximize sensing contrast. By default, the optimization maximizes the detection probability `1 - P(00)` (any outcome except ground state).

# %%
import optax
# Optimize with default detection criterion (1 - P(00))
callback_opt = experiment.optimize_rotations(
    num_steps=300,
    batch_size=1,
    tolerance=1e-8,
    verbose=True,
    verbose_step=15,
    initial_values=[np.pi/3, np.pi/4,-np.pi/3, -np.pi],
    renormalize_grad=False,
    optimizer=optax.sgd(learning_rate=0.01)
)
# Out:
# Configuration:
#     Max iterations: 300
#     Batch size: 1
#     Convergence tolerance: 1.00e-08
#     Detection criterion: 1 - P(0)
#     Trainable parameters: 4 (2 initial circuit + 2 final circuit)
#     Initial parameter values:
#         param0. setup_=1.047 rad (60.0°)
#         param1. setup_=0.785 rad (45.0°)
#         param2. reset_=-1.047 rad (-60.0°)
#         param3. reset_=-3.142 rad (-180.0°)
# ===========================================================================
# Step  setup_0     setup_1     reset_0     reset_1     Contrast    Grad Norm
# ---------------------------------------------------------------------------
# 0     1.047198    0.785398    -1.047198   -3.141593   0.020831    7.79e-02
# 15    1.047802    0.793591    -1.047782   -3.133327   0.021738    7.76e-02
# 30    1.048424    0.801745    -1.048384   -3.125103   0.022637    7.72e-02
# 45    1.049061    0.809850    -1.049002   -3.116928   0.023526    7.67e-02
# 60    1.049714    0.817898    -1.049637   -3.108811   0.024402    7.61e-02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 import optax
#       2 # Optimize with default detection criterion (1 - P(00))
# ----> 3 callback_opt = experiment.optimize_rotations(
#       4     num_steps=300,
#       5     batch_size=1,
#       6     tolerance=1e-8,
#       7     verbose=True,
#       8     verbose_step=15,
#       9     initial_values=[np.pi/3, np.pi/4,-np.pi/3, -np.pi],
#      10     renormalize_grad=False,
#      11     optimizer=optax.sgd(learning_rate=0.01)
#      12 )
#
# File ~\Code\Quantum-sensing-QML\src\qsopt\core\experiment\experiment.py:1130, in Experiment.optimize_rotations(self, num_steps, batch_size, tolerance, verbose, verbose_step, callback, initial_values, loss_function, optimizer, renormalize_grad)
#    1126 grad_norm = float("inf")
#    1128 for step in range(num_steps):
#    1129     # Compute gradients using JAX autodiff
# -> 1130     grads, (prob_with, prob_without, sensing_contrast) = jax.grad(
#    1131         objective_function, has_aux=True
#    1132     )(params)
#    1134     # Track best parameters
#    1135     if sensing_contrast > best_contrast:
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\simon\miniconda3\envs\quantum\Lib\site-packages\jax\_src\api.py:398, in grad.<locals>.grad_f_aux(*args, **kwargs)
#     395 @wraps(fun, docstr=docstr, argnums=argnums)
#     396 @api_boundary
#     397 def grad_f_aux(*args, **kwargs):
# --> 398   (_, aux), g = value_and_grad_f(*args, **kwargs)
#     399   return g, aux
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\simon\miniconda3\envs\quantum\Lib\site-packages\jax\_src\api.py:468, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     466 _check_scalar(ans)
#     467 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 468 g = vjp_py(lax_internal._one(ans))
#     469 g = g[0] if isinstance(argnums, int) else g
#     470 if not has_aux:
#
# File c:\Users\simon\miniconda3\envs\quantum\Lib\site-packages\jax\_src\tree_util.py:477, in _HashableCallableShim.__call__(self, *args, **kw)
#     476 def __call__(self, *args, **kw):
# --> 477   return self.fun(*args, **kw)
#
# File c:\Users\simon\miniconda3\envs\quantum\Lib\site-packages\jax\_src\api.py:1886, in _vjp_pullback_wrapper(name, out_primal_avals, io_tree, fun, *py_args_)
#    1879   if (not core.typecompat(ct_aval, ct_aval_expected) and
#    1880       not _temporary_dtype_exception(ct_aval, ct_aval_expected)):
#    1881     raise ValueError(
#    1882         "unexpected JAX type (e.g. shape/dtype) for argument to vjp function: "
#    1883         f"got {ct_aval.str_short()}, but expected {ct_aval_expected.str_short()} "
#    1884         f"because the corresponding output of the function {name} had JAX type "
#    1885         f"{aval.str_short()}")
# -> 1886 ans = fun(*args)
#    1887 return tree_unflatten(out_tree, ans)
#
# File c:\Users\simon\miniconda3\envs\quantum\Lib\site-packages\jax\_src\tree_util.py:477, in _HashableCallableShim.__call__(self, *args, **kw)
#     476 def __call__(self, *args, **kw):
# --> 477   return self.fun(*args, **kw)
#
# File c:\Users\simon\miniconda3\envs\quantum\Lib\site-packages\jax\_src\interpreters\ad.py:149, in vjp.<locals>.unbound_vjp(pvals, jaxpr, consts, *cts)
#     147 cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#     148 dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 149 arg_cts = backward_pass(jaxpr, True, consts, dummy_args, cts)
#     150 return map(instantiate_zeros, arg_cts)
#
# File c:\Users\simon\miniconda3\envs\quantum\Lib\site-packages\jax\_src\interpreters\ad.py:237, in backward_pass(jaxpr, transform_stack, consts, primals_in, cotangents_in)
#     234   cts_out = get_primitive_transpose(eqn.primitive)(
#     235       params, call_jaxpr, invals, cts_in, cts_in_avals)
#     236 elif eqn.primitive in reducing_transposes:
# --> 237   cts_out = reducing_transposes[eqn.primitive](
#     238       cts_in, *invals, **eqn.params)
#     239 else:
#     240   cts_out = get_primitive_transpose(eqn.primitive)(
#     241       cts_in, *invals, **eqn.params)
#
# File c:\Users\simon\miniconda3\envs\quantum\Lib\site-packages\jax\_src\pjit.py:2297, in _pjit_transpose(cts_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *primals_in)
#    2294   transpose_in_layouts = (None,) * len(attrs_tracked) + transpose_in_layouts
#    2295   transpose_out_layouts = (None,) * len(attrs_tracked) + transpose_out_layouts
# -> 2297 nz_cts_out = pjit_p.bind(
#    2298     *primals_and_nz_cts_in,
#    2299     jaxpr=transpose_jaxpr,
#    2300     in_shardings=transpose_in_shardings,
#    2301     out_shardings=transpose_out_shardings,
#    2302     in_layouts=transpose_in_layouts,
#    2303     out_layouts=transpose_out_layouts,
#    2304     resource_env=resource_env,
#    2305     donated_invars=(False,) * len(primals_and_nz_cts_in),
#    2306     name=name,
#    2307     keep_unused=keep_unused,
#    2308     inline=inline)
#    2310 if attrs_tracked:
#    2311   final_states, nz_cts_out = split_list(nz_cts_out, [len(init_states)])
#
# File c:\Users\simon\miniconda3\envs\quantum\Lib\site-packages\jax\_src\core.py:2803, in AxisPrimitive.bind(self, *args, **params)
#    2799 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2800                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2801 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2802              else axis_main.with_cur_sublevel())
# -> 2803 return self.bind_with_trace(top_trace, args, params)
#
# File c:\Users\simon\miniconda3\envs\quantum\Lib\site-packages\jax\_src\core.py:442, in Primitive.bind_with_trace(self, trace, args, params)
#     440 def bind_with_trace(self, trace, args, params):
#     441   with pop_level(trace.level):
# --> 442     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     443   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File c:\Users\simon\miniconda3\envs\quantum\Lib\site-packages\jax\_src\core.py:955, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     953   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     954 else:
# --> 955   return primitive.impl(*tracers, **params)
#
# File c:\Users\simon\miniconda3\envs\quantum\Lib\site-packages\jax\_src\pjit.py:1738, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1729 donated_argnums = tuple(i for i, d in enumerate(donated_invars) if d)
#    1730 cache_key = pxla.JitGlobalCppCacheKeys(
#    1731     donate_argnums=donated_argnums, donate_argnames=None,
#    1732     device=None, backend=None,
#    (...)   1736     out_layouts_treedef=None, out_layouts_leaves=out_layouts,
#    1737     use_resource_env=resource_env is not None)
# -> 1738 return xc._xla.pjit(
#    1739     name, f, call_impl_cache_miss, [], [], cache_key,
#    1740     tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1741     _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualize Optimization Progress
#
# Let's plot how the contrast evolved during optimization:

# %%
from qsopt.utils.visualization import plot_optimization_dashboard

# Create comprehensive dashboard showing all optimization metrics
fig = plot_optimization_dashboard(
    callback_opt,
    show_contrast=True,
    show_gradients=True,
    show_parameters=True,
    show_trajectory=True,
    show_probabilities=True,
    figsize=(16, 14)
)
plt.show()
